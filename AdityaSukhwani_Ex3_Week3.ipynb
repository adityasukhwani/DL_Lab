# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasukhwani/DL_Lab/blob/master/AdityaSukhwani_Ex3_Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **MNIST DATASET**

# %%
data1 = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = data1.load_data()
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train[0].shape
# Out:
# (28, 28)

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
#q1
model1 = tf.keras.Sequential()
model1.add(tf.keras.Input(shape = (28,28,1)))
model1.add(tf.keras.layers.Conv2D(32, kernel_size=(5,5), activation="relu", padding="valid"))
model1.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model1.add(tf.keras.layers.Flatten())
model1.add(tf.keras.layers.Dense(100, activation="relu", name="hiddenlayer"))
model1.add(tf.keras.layers.Dense(10, activation="softmax", name="outputlayer"))

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 24, 24, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 32)       0
#  )
#
#  flatten (Flatten)           (None, 4608)              0
#
#  hiddenlayer (Dense)         (None, 100)               460900
#
#  outputlayer (Dense)         (None, 10)                1010
#
# ...
# Total params: 462,742
# Trainable params: 462,742
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss ="sparse_categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])
history1 = model1.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 12s 4ms/step - loss: 0.1439 - accuracy: 0.9570 - val_loss: 0.0602 - val_accuracy: 0.9840
# Epoch 2/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0489 - accuracy: 0.9847 - val_loss: 0.0481 - val_accuracy: 0.9887
# Epoch 3/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0323 - accuracy: 0.9894 - val_loss: 0.0418 - val_accuracy: 0.9892
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.0480 - val_accuracy: 0.9868
# Epoch 5/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0165 - accuracy: 0.9946 - val_loss: 0.0556 - val_accuracy: 0.9868
# Epoch 6/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.0474 - val_accuracy: 0.9897
# Epoch 7/10
# ...

# %%
#q2
model2 = tf.keras.Sequential()
model2.add(tf.keras.Input(shape = (28,28,1)))
model2.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation="relu", padding="valid"))
model2.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation="relu", padding="valid"))
model2.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model2.add(tf.keras.layers.Flatten())
model2.add(tf.keras.layers.Dense(100, activation="relu", name="hiddenlayer"))
model2.add(tf.keras.layers.Dense(10, activation="softmax", name="outputlayer"))

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  hiddenlayer (Dense)         (None, 100)               460900
#
#  outputlayer (Dense)         (None, 10)                1010
#
# ...
# Total params: 471,478
# Trainable params: 471,478
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss ="sparse_categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])
history2 = model2.fit(x_train, y_train, batch_size=32, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1314 - accuracy: 0.9587 - val_loss: 0.0534 - val_accuracy: 0.9845
# Epoch 2/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0424 - accuracy: 0.9867 - val_loss: 0.0434 - val_accuracy: 0.9880
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0260 - accuracy: 0.9918 - val_loss: 0.0399 - val_accuracy: 0.9893
# Epoch 4/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.0503 - val_accuracy: 0.9873
# Epoch 5/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.0442 - val_accuracy: 0.9888
# Epoch 6/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.0445 - val_accuracy: 0.9892
# Epoch 7/10
# ...

# %%
#q3
model3 = tf.keras.Sequential()
model3.add(tf.keras.Input(shape = (28,28,1)))
model3.add(tf.keras.layers.Conv2D(6, kernel_size=(5,5), activation="tanh", padding="same"))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2) , padding="valid"))
model3.add(tf.keras.layers.Conv2D(16, kernel_size=(5,5), activation="tanh", padding="valid"))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides =(2,2), padding="valid"))
model3.add(tf.keras.layers.Flatten())
model3.add(tf.keras.layers.Dense(120, activation="sigmoid", name="hiddenlayer1"))
model3.add(tf.keras.layers.Dense(84, activation="sigmoid", name="hiddenlayer2"))
model3.add(tf.keras.layers.Dense(10, activation="softmax", name="outputlayer"))

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 28, 28, 6)         156
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 6)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 16)        2416
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 400)               0
#
#  hiddenlayer1 (Dense)        (None, 120)               48120
#
#  hiddenlayer2 (Dense)        (None, 84)                10164
#
#  outputlayer (Dense)         (None, 10)                850
#
# ...
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(loss ="sparse_categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])
history3 = model3.fit(x_train, y_train, batch_size=32, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.3211 - accuracy: 0.9210 - val_loss: 0.0668 - val_accuracy: 0.9813
# Epoch 2/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0642 - accuracy: 0.9806 - val_loss: 0.0487 - val_accuracy: 0.9853
# Epoch 3/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0430 - accuracy: 0.9871 - val_loss: 0.0496 - val_accuracy: 0.9865
# Epoch 4/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0327 - accuracy: 0.9900 - val_loss: 0.0392 - val_accuracy: 0.9887
# Epoch 5/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0241 - accuracy: 0.9924 - val_loss: 0.0451 - val_accuracy: 0.9873
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0195 - accuracy: 0.9938 - val_loss: 0.0414 - val_accuracy: 0.9878
# Epoch 7/10
# ...

# %% [markdown]
# Q4- Compare the performances of theabove three architectureswith respect to the two datasets.

# %%
model1.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0456 - accuracy: 0.9878
# [0.045595359057188034, 0.9878000020980835]

# %%
model2.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0485 - accuracy: 0.9887
# [0.048518724739551544, 0.9886999726295471]

# %%
model3.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0379 - accuracy: 0.9887
# [0.03792219236493111, 0.9886999726295471]

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.plot(history1.history["accuracy"])
plt.plot(history1.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])

plt.subplot(1,2,2)
plt.plot(history1.history["loss"])
plt.plot(history1.history["val_loss"])
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])


plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.plot(history2.history["accuracy"])
plt.plot(history2.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])

plt.subplot(1,2,2)
plt.plot(history2.history["loss"])
plt.plot(history2.history["val_loss"])
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])


plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.plot(history3.history["accuracy"])
plt.plot(history3.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])

plt.subplot(1,2,2)
plt.plot(history3.history["loss"])
plt.plot(history3.history["val_loss"])
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])


plt.show()

# %% [markdown]
# **CIFAR-10 DATASET**

# %%
data2 = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = data2.load_data()
# Out:
# ...
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
x_train[0].shape
# Out:
# (32, 32, 3)

# %%
no_of_unqclasses, index=np.unique(y_train, return_index= True)
print(len(no_of_unqclasses))
print(index)
# Out:
# 10
# [29  4  6  9  3 27  0  7  8  1]

# %%
for i in index:
  plt.figure(i)
  plt.imshow(x_train[i])
plt.show()

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
#q1
model4 = tf.keras.Sequential()
model4.add(tf.keras.Input(shape = (32,32,3)))
model4.add(tf.keras.layers.Conv2D(32, kernel_size=(5,5), activation="relu", padding="valid"))
model4.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model4.add(tf.keras.layers.Flatten())
model4.add(tf.keras.layers.Dense(100, activation="relu", name="hiddenlayer"))
model4.add(tf.keras.layers.Dense(10, activation="softmax", name="outputlayer"))

# %%
model4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        2432
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  hiddenlayer (Dense)         (None, 100)               627300
#
#  outputlayer (Dense)         (None, 10)                1010
#
# ...
# Total params: 630,742
# Trainable params: 630,742
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4.compile(loss ="sparse_categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])
history4 = model4.fit(x_train, y_train, epochs=15, validation_split=0.3)
# Out:
# Epoch 1/15
# 1094/1094 [==============================] - 16s 4ms/step - loss: 1.5730 - accuracy: 0.4353 - val_loss: 1.3555 - val_accuracy: 0.5228
# Epoch 2/15
# 1094/1094 [==============================] - 4s 4ms/step - loss: 1.2786 - accuracy: 0.5478 - val_loss: 1.3133 - val_accuracy: 0.5378
# Epoch 3/15
# 1094/1094 [==============================] - 5s 4ms/step - loss: 1.1525 - accuracy: 0.5942 - val_loss: 1.1760 - val_accuracy: 0.5960
# Epoch 4/15
# 1094/1094 [==============================] - 5s 4ms/step - loss: 1.0455 - accuracy: 0.6373 - val_loss: 1.1864 - val_accuracy: 0.5903
# Epoch 5/15
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.9693 - accuracy: 0.6623 - val_loss: 1.1305 - val_accuracy: 0.6074
# Epoch 6/15
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.8940 - accuracy: 0.6893 - val_loss: 1.1330 - val_accuracy: 0.6144
# Epoch 7/15
# ...

# %%
model4.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4282 - accuracy: 0.6157
# [1.4281883239746094, 0.6157000064849854]

# %%
#q2
model5 = tf.keras.Sequential()
model5.add(tf.keras.Input(shape = (32,32,3)))
model5.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation="relu", padding="valid"))
model5.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation="relu", padding="valid"))
model5.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model5.add(tf.keras.layers.Flatten())
model5.add(tf.keras.layers.Dense(100, activation="relu", name="hiddenlayer"))
model5.add(tf.keras.layers.Dense(10, activation="softmax", name="outputlayer"))

# %%
model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 30, 30, 32)        896
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten_4 (Flatten)         (None, 6272)              0
#
#  hiddenlayer (Dense)         (None, 100)               627300
#
#  outputlayer (Dense)         (None, 10)                1010
#
# ...
# Total params: 638,454
# Trainable params: 638,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model5.compile(loss ="sparse_categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])
history5 = model5.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.4518 - accuracy: 0.4805 - val_loss: 1.2299 - val_accuracy: 0.5694
# Epoch 2/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.1138 - accuracy: 0.6065 - val_loss: 1.0789 - val_accuracy: 0.6216
# Epoch 3/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.9749 - accuracy: 0.6584 - val_loss: 1.0042 - val_accuracy: 0.6542
# Epoch 4/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.8912 - accuracy: 0.6872 - val_loss: 0.9676 - val_accuracy: 0.6720
# Epoch 5/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.8130 - accuracy: 0.7147 - val_loss: 0.9539 - val_accuracy: 0.6736
# Epoch 6/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.7420 - accuracy: 0.7410 - val_loss: 0.9605 - val_accuracy: 0.6806
# Epoch 7/10
# ...

# %%
model5.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2008 - accuracy: 0.6548
# [1.2007542848587036, 0.6547999978065491]

# %%
#q3
model6 = tf.keras.Sequential()
model6.add(tf.keras.Input(shape = (32,32,3)))
model6.add(tf.keras.layers.Conv2D(6, kernel_size=(5,5), activation="tanh", padding="valid"))
model6.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2) , padding="valid"))
model6.add(tf.keras.layers.Conv2D(16, kernel_size=(5,5), activation="tanh", padding="valid"))
model6.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides =(2,2), padding="valid"))
model6.add(tf.keras.layers.Flatten())
model6.add(tf.keras.layers.Dense(120, activation="sigmoid", name="hiddenlayer1"))
model6.add(tf.keras.layers.Dense(84, activation="sigmoid", name="hiddenlayer2"))
model6.add(tf.keras.layers.Dense(10, activation="softmax", name="outputlayer"))

# %%
model6.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 28, 28, 6)         456
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 6)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 16)        2416
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 400)               0
#
#  hiddenlayer1 (Dense)        (None, 120)               48120
#
#  hiddenlayer2 (Dense)        (None, 84)                10164
#
#  outputlayer (Dense)         (None, 10)                850
#
# ...
# Total params: 62,006
# Trainable params: 62,006
# Non-trainable params: 0
# _________________________________________________________________

# %%
model6.compile(loss ="sparse_categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])
history6 = model6.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.7119 - accuracy: 0.3732 - val_loss: 1.5022 - val_accuracy: 0.4420
# Epoch 2/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.4277 - accuracy: 0.4861 - val_loss: 1.3521 - val_accuracy: 0.5060
# Epoch 3/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.3033 - accuracy: 0.5324 - val_loss: 1.2954 - val_accuracy: 0.5380
# Epoch 4/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.2129 - accuracy: 0.5671 - val_loss: 1.1973 - val_accuracy: 0.5716
# Epoch 5/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.1430 - accuracy: 0.5946 - val_loss: 1.1686 - val_accuracy: 0.5814
# Epoch 6/10
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.0920 - accuracy: 0.6111 - val_loss: 1.1355 - val_accuracy: 0.5990
# Epoch 7/10
# ...

# %%
model6.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1461 - accuracy: 0.5999
# [1.1460914611816406, 0.5999000072479248]

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.plot(history4.history["accuracy"])
plt.plot(history4.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])

plt.subplot(1,2,2)
plt.plot(history4.history["loss"])
plt.plot(history4.history["val_loss"])
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])


plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.plot(history5.history["accuracy"])
plt.plot(history5.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])

plt.subplot(1,2,2)
plt.plot(history5.history["loss"])
plt.plot(history5.history["val_loss"])
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])


plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.plot(history6.history["accuracy"])
plt.plot(history6.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])

plt.subplot(1,2,2)
plt.plot(history6.history["loss"])
plt.plot(history6.history["val_loss"])
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])


plt.show()
