# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasukhwani/DL_Lab/blob/master/AdityaSukhwani_Ex1_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
data = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = data.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# **Q1 Find the number of classes**

# %%
no_of_classes, index =np.unique(y_train, return_index = True)
print(len(no_of_classes))
print(index)
# Out:
# 10
# [ 1 16  5  3 19  8 18  6 23  0]

# %% [markdown]
# **Q2 Find the dimension of each image**

# %%
x_train[0].shape
# Out:
# (28, 28)

# %% [markdown]
# **Q3 Display one image of each class**

# %%
for i in index:
  plt.figure(i)
  plt.imshow(x_train[i], cmap ='gray')
plt.show()

# %% [markdown]
# **Q4 Perform normalization**

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %% [markdown]
# Q5 Build two neural network with 2 hidden layer and 5 hidden layer

# %%
model1 = tf.keras.Sequential()
model1.add(tf.keras.layers.Flatten(input_shape =[28, 28], name = "inputlayer"))
model1.add(tf.keras.layers.Dense(300, activation ="relu", name = "hiddenlayer1"))
model1.add(tf.keras.layers.Dense(100, activation ="relu", name = "hiddenlayer2"))
model1.add(tf.keras.layers.Dense(10, activation ="softmax", name = "outputlayer"))

# %%
model2 =tf.keras.Sequential()
model2.add(tf.keras.layers.Flatten(input_shape =[28,28], name = "inputlayer"))
model2.add(tf.keras.layers.Dense(650, activation ="relu", name = "hiddenlayer1"))
model2.add(tf.keras.layers.Dense(550, activation ="relu", name = "hiddenlayer2"))
model2.add(tf.keras.layers.Dense(420, activation ="relu", name = "hiddenlayer3"))
model2.add(tf.keras.layers.Dense(260, activation ="relu", name = "hiddenlayer4"))
model2.add(tf.keras.layers.Dense(100, activation ="relu", name = "hiddenlayer5"))
model2.add(tf.keras.layers.Dense(10, activation ="softmax", name = "outputlayer"))

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inputlayer (Flatten)        (None, 784)               0
#
#  hiddenlayer1 (Dense)        (None, 300)               235500
#
#  hiddenlayer2 (Dense)        (None, 100)               30100
#
#  outputlayer (Dense)         (None, 10)                1010
#
# ...
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inputlayer (Flatten)        (None, 784)               0
#
#  hiddenlayer1 (Dense)        (None, 650)               510250
#
#  hiddenlayer2 (Dense)        (None, 550)               358050
#
#  hiddenlayer3 (Dense)        (None, 420)               231420
#
#  hiddenlayer4 (Dense)        (None, 260)               109460
#
#  hiddenlayer5 (Dense)        (None, 100)               26100
#
#  outputlayer (Dense)         (None, 10)                1010
#
# ...
# Total params: 1,236,290
# Trainable params: 1,236,290
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Q6 Train and test the above two networks**

# %%
model1.compile(loss ="sparse_categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])
history1 = model1.fit(x_train, y_train, batch_size=32, epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 1688/1688 [==============================] - 8s 3ms/step - loss: 0.4805 - accuracy: 0.8270 - val_loss: 0.3826 - val_accuracy: 0.8582
# Epoch 2/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.3628 - accuracy: 0.8664 - val_loss: 0.4168 - val_accuracy: 0.8472
# Epoch 3/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.3263 - accuracy: 0.8793 - val_loss: 0.3371 - val_accuracy: 0.8767
# Epoch 4/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.3048 - accuracy: 0.8867 - val_loss: 0.3630 - val_accuracy: 0.8717
# Epoch 5/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.2852 - accuracy: 0.8951 - val_loss: 0.3205 - val_accuracy: 0.8825
# Epoch 6/20
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.2710 - accuracy: 0.8981 - val_loss: 0.3621 - val_accuracy: 0.8748
# Epoch 7/20
# ...

# %%
model2.compile(loss ="sparse_categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])
history2 = model2.fit(x_train, y_train, batch_size=32, epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.5114 - accuracy: 0.8144 - val_loss: 0.4077 - val_accuracy: 0.8548
# Epoch 2/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.3870 - accuracy: 0.8614 - val_loss: 0.3648 - val_accuracy: 0.8680
# Epoch 3/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.3477 - accuracy: 0.8749 - val_loss: 0.3853 - val_accuracy: 0.8580
# Epoch 4/20
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.3203 - accuracy: 0.8849 - val_loss: 0.3651 - val_accuracy: 0.8705
# Epoch 5/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.3056 - accuracy: 0.8873 - val_loss: 0.3456 - val_accuracy: 0.8758
# Epoch 6/20
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2871 - accuracy: 0.8954 - val_loss: 0.3530 - val_accuracy: 0.8752
# Epoch 7/20
# ...

# %%
model1.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3674 - accuracy: 0.8931
# [0.3673636019229889, 0.8931000232696533]

# %%
model2.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4223 - accuracy: 0.8850
# [0.42230239510536194, 0.8849999904632568]

# %% [markdown]
# **Q7 Compare their performances**

# %%
# plot for neural network with 2 hidden layers
plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.plot(history1.history["accuracy"])
plt.plot(history1.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])

plt.subplot(1,2,2)
plt.plot(history1.history["loss"])
plt.plot(history1.history["val_loss"])
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])


plt.show()

# %%
# plot for neural network with 5 hidden layers
plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.plot(history2.history["accuracy"])
plt.plot(history2.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])

plt.subplot(1,2,2)
plt.plot(history2.history["loss"])
plt.plot(history2.history["val_loss"])
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])


plt.show()
